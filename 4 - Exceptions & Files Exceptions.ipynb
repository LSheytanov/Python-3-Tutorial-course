# %%
num1 = 7
num2 = 0
print(num1/num2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-e4e18557d959> in <module>
#       1 num1 = 7
#       2 num2 = 0
# ----> 3 print(num1/num2)
#
# ZeroDivisionError: division by zero

# %%
try:
   num1 = 7
   num2 = 0
   print (num1 / num2)
   print("Done calculation")
# Out:
#   File "<ipython-input-2-41c863d07694>", line 5
#     print("Done calculation")
#                              ^
# SyntaxError: unexpected EOF while parsing

# %%
try:
   num1 = 7
   num2 = 0
   print (num1 / num2)
   print("Done calculation")
except ZeroDivisionError:
   print("An error occurred")
   print("due to zero division")
# Out:
# An error occurred
# due to zero division

# %%
try:
   variable = 10
   print(variable + "hello")
   print(variable / 2)
except ZeroDivisionError:
   print("Divided by zero")
except (ValueError, TypeError):
   print("Error occurred")
# Out:
# Error occurred

# %%
#An except statement without any exception specified will catch all errors. 
#These should be used sparingly, as they can catch unexpected errors and hide programming mistakes.

# %%
try:
   word = "spam"
   print(word / 0)
except:
   print("An error occurred")
# Out:
# An error occurred

# %%
try:
   print("Hello")
   print(1 / 0)
except ZeroDivisionError:
   print("Divided by zero")
finally:
   print("This code will run no matter what")
# Out:
# Hello
# Divided by zero
# This code will run no matter what

# %%
try:
   print(1)
   print(10 / 0)
except ZeroDivisionError:
   print(unknown_var)
finally:
   print("This is executed last")
# Out:
# 1
# This is executed last
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-f04ca731aa16> in <module>
#       2    print(1)
# ----> 3    print(10 / 0)
#       4 except ZeroDivisionError:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f04ca731aa16> in <module>
#       3    print(10 / 0)
#       4 except ZeroDivisionError:
# ----> 5    print(unknown_var)
#       6 finally:
#       7    print("This is executed last")
#
# NameError: name 'unknown_var' is not defined

# %%
#Code in a finally statement even runs if an uncaught exception occurs in one of the preceding blocks.

# %%
print(1)
raise ValueError
print(2)
# Out:
# 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-990863ff3a0f> in <module>
#       1 print(1)
# ----> 2 raise ValueError
#       3 print(2)
#
# ValueError:

# %%
#You need to specify the type of the exception raised.

# %%
name = "123"
raise NameError("Invalid name!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d5ceb78ca603> in <module>
#       1 name = "123"
# ----> 2 raise NameError("Invalid name!")
#
# NameError: Invalid name!

# %%
try:
   num = 5 / 0
except:
   print("An error occurred")
   raise
# Out:
# An error occurred
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-cd653ca0b502> in <module>
#       1 try:
# ----> 2    num = 5 / 0
#       3 except:
#       4    print("An error occurred")
#       5    raise
#
# ZeroDivisionError: division by zero

# %%
print(1)
assert 2 + 2 == 4
print(2)
assert 1 + 1 == 3
print(3)
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-14-98aeb3b8a49e> in <module>
#       2 assert 2 + 2 == 4
#       3 print(2)
# ----> 4 assert 1 + 1 == 3
#       5 print(3)
#
# AssertionError:

# %%
temp = -10
assert (temp >= 0), "Colder than absolute zero!"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-b5d283b4e7fd> in <module>
#       1 temp = -10
# ----> 2 assert (temp >= 0), "Colder than absolute zero!"
#
# AssertionError: Colder than absolute zero!

# %%
myfile = open("filename.txt")

# %%
#If the file is in the current working directory of the program, you can specify only its name.

# %%
# write mode
open("filename.txt", "w")

# read mode
open("filename.txt", "r")
open("filename.txt")

# binary write mode
open("filename.txt", "wb")
# Out:
# <_io.BufferedWriter name='filename.txt'>

# %%
file = open("filename.txt", "w")
# do stuff to the file
file.close()

# %%
file = open("filename.txt", "r")
cont = file.read()
print(cont)
file.close()

# %%
file = open("filename.txt", "r")
print(file.read(16))
print(file.read(4))
print(file.read(4))
print(file.read())
file.close()

# %%
#Just like passing no arguments, negative values will return the entire contents.

# %%
file = open("filename.txt", "r")
file.read()
print("Re-reading")
print(file.read())
print("Finished")
file.close()
# Out:
# Re-reading
#
# Finished

# %%
file = open("filename.txt", "r")
str = file.read()
print(len(str))
file.close()
# Out:
# 0

# %%
file = open("filename.txt", "r")
print(file.readlines())
file.close()
# Out:
# []

# %%
file = open("filename.txt", "r")

for line in file:
    print(line)

file.close()

# %%
file = open("newfile.txt", "w")
file.write("This has been written to a file")
file.close()

file = open("newfile.txt", "r")
print(file.read())
file.close()
# Out:
# This has been written to a file

# %%
#The "w" mode will create a file, if it does not already exist.

# %%
file = open("newfile.txt", "r")
print("Reading initial contents")
print(file.read())
print("Finished")
file.close()

file = open("newfile.txt", "w")
file.write("Some new text")
file.close()

file = open("newfile.txt", "r")
print("Reading new contents")
print(file.read())
print("Finished")
file.close()
# Out:
# Reading initial contents
# This has been written to a file
# Finished
# Reading new contents
# Some new text
# Finished

# %%
#When a file is opened in write mode, the file's existing content is deleted.

# %%
msg = "Hello world!"
file = open("newfile.txt", "w")
amount_written = file.write(msg)
print(amount_written)
file.close()
# Out:
# 12

# %%
#To write something other than a string, it needs to be converted to a string first.

# %%
try:
   f = open("filename.txt")
   print(f.read())
finally:
   f.close()

# %%
with open("filename.txt") as f:
   print(f.read())

# %%
#An alternative way of doing this is using with statements. 
#This creates a temporary variable (often called f), which is only accessible in the indented block of the with statement.

# %%
#The file is automatically closed at the end of the with statement, even if exceptions occur within it.
